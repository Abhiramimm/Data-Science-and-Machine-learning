# %%
import numpy as np
import pandas as pd 
import seaborn as sns 
# plots
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("iris.csv")

# %%
g = sns.pairplot(df)

# %%
g = sns.pairplot(df, kind="reg", hue="variety")

# %%
g = sns.pairplot(df, kind="kde", hue="variety")

# %%
g = sns.pairplot(df, kind="scatter", hue="variety")

# %%
g = sns.pairplot(df, height=3, vars=["sepal.width", "sepal.length"], \
                markers=["o", "s", "D"], hue="variety")

# %%
g = sns.pairplot(df, kind="hist", hue="variety")
